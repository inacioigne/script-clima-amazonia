# %%
from os import listdir

# %%
eds = []
for i in listdir("data/pdf/2024"):
    if "PT" in i:
        ed = i.replace(".pdf", "")
        eds.append(ed)
        
eds = sorted(eds)
eds = [i[7:] for i in eds]

# %%
for i in eds:
    pathPT = f"data/pdf/2024/BHA_PT_{i}.pdf"
    pathEN = f"data/pdf/2024/BHA_EN_{i}.pdf"
    pathES = f"data/pdf/2024/BHA_ES_{i}.pdf"
    bulletin_dict = get_text(pathPT, yyyy, mmdd)
    print(pathPT)
# Out:
# data/pdf/2024/BHA_PT_20240103.pdf
# data/pdf/2024/BHA_PT_20240110.pdf
# data/pdf/2024/BHA_PT_20240117.pdf
# data/pdf/2024/BHA_PT_20240124.pdf
# data/pdf/2024/BHA_PT_20240131.pdf
# data/pdf/2024/BHA_PT_20240207.pdf
# data/pdf/2024/BHA_PT_20240214.pdf
# data/pdf/2024/BHA_PT_20240221.pdf
# data/pdf/2024/BHA_PT_20240228.pdf
# data/pdf/2024/BHA_PT_20240306.pdf
# data/pdf/2024/BHA_PT_20240313.pdf
# data/pdf/2024/BHA_PT_20240320.pdf
# data/pdf/2024/BHA_PT_20240327.pdf
# data/pdf/2024/BHA_PT_20240403.pdf
# data/pdf/2024/BHA_PT_20240410.pdf
# data/pdf/2024/BHA_PT_20240417.pdf
# data/pdf/2024/BHA_PT_20240424.pdf
# data/pdf/2024/BHA_PT_20240501.pdf
# data/pdf/2024/BHA_PT_20240508.pdf
# data/pdf/2024/BHA_PT_20240515.pdf
# data/pdf/2024/BHA_PT_20240522.pdf
# data/pdf/2024/BHA_PT_20240529.pdf
# data/pdf/2024/BHA_PT_20240605.pdf
# data/pdf/2024/BHA_PT_20240612.pdf
# data/pdf/2024/BHA_PT_20240619.pdf
# data/pdf/2024/BHA_PT_20240626.pdf
# data/pdf/2024/BHA_PT_20240703.pdf
# data/pdf/2024/BHA_PT_20240710.pdf
# data/pdf/2024/BHA_PT_20240717.pdf
# data/pdf/2024/BHA_PT_20240724.pdf
# data/pdf/2024/BHA_PT_20240731.pdf
# data/pdf/2024/BHA_PT_20240807.pdf
# data/pdf/2024/BHA_PT_20240814.pdf
# data/pdf/2024/BHA_PT_20240821.pdf
# data/pdf/2024/BHA_PT_20240828.pdf
# data/pdf/2024/BHA_PT_20240904.pdf
# data/pdf/2024/BHA_PT_20240911.pdf
# data/pdf/2024/BHA_PT_20240918.pdf
# data/pdf/2024/BHA_PT_20240925.pdf
# data/pdf/2024/BHA_PT_20241002.pdf
# data/pdf/2024/BHA_PT_20241009.pdf
# data/pdf/2024/BHA_PT_20241016.pdf
# data/pdf/2024/BHA_PT_20241023.pdf
# data/pdf/2024/BHA_PT_20241030.pdf
# data/pdf/2024/BHA_PT_20241106.pdf
# data/pdf/2024/BHA_PT_20241113.pdf
# data/pdf/2024/BHA_PT_20241120.pdf
# data/pdf/2024/BHA_PT_20241127.pdf
# data/pdf/2024/BHA_PT_20241204.pdf
# data/pdf/2024/BHA_PT_20241211.pdf
# data/pdf/2024/BHA_PT_20241217.pdf
# data/pdf/2024/BHA_PT_20241225.pdf

# %%
for mmdd in eds:
    number = f"{yyyy}{mmdd}"
    pathPT = f"/home/inacio/script-clima-amazonia/pdfs/BHA_PT_{number}.pdf"
    pathEN = f"/home/inacio/script-clima-amazonia/pdfs/BHA_EN_{number}.pdf"
    pathES = f"/home/inacio/script-clima-amazonia/pdfs/BHA_ES_{number}.pdf"
# Out:
# ['BHA_PT_20240103',
#  'BHA_PT_20240110',
#  'BHA_PT_20240117',
#  'BHA_PT_20240124',
#  'BHA_PT_20240131',
#  'BHA_PT_20240207',
#  'BHA_PT_20240214',
#  'BHA_PT_20240221',
#  'BHA_PT_20240228',
#  'BHA_PT_20240306',
#  'BHA_PT_20240313',
#  'BHA_PT_20240320',
#  'BHA_PT_20240327',
#  'BHA_PT_20240403',
#  'BHA_PT_20240410',
#  'BHA_PT_20240417',
#  'BHA_PT_20240424',
#  'BHA_PT_20240501',
#  'BHA_PT_20240508',
#  'BHA_PT_20240515',
#  'BHA_PT_20240522',
#  'BHA_PT_20240529',
#  'BHA_PT_20240605',
#  'BHA_PT_20240612',
#  'BHA_PT_20240619',
#  'BHA_PT_20240626',
#  'BHA_PT_20240703',
#  'BHA_PT_20240710',
#  'BHA_PT_20240717',
#  'BHA_PT_20240724',
#  'BHA_PT_20240731',
#  'BHA_PT_20240807',
#  'BHA_PT_20240814',
#  'BHA_PT_20240821',
#  'BHA_PT_20240828',
#  'BHA_PT_20240904',
#  'BHA_PT_20240911',
#  'BHA_PT_20240918',
#  'BHA_PT_20240925',
#  'BHA_PT_20241002',
#  'BHA_PT_20241009',
#  'BHA_PT_20241016',
#  'BHA_PT_20241023',
#  'BHA_PT_20241030',
#  'BHA_PT_20241106',
#  'BHA_PT_20241113',
#  'BHA_PT_20241120',
#  'BHA_PT_20241127',
#  'BHA_PT_20241204',
#  'BHA_PT_20241211',
#  'BHA_PT_20241217',
#  'BHA_PT_20241225']
